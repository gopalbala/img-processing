# %%
import cv2
import numpy as numpy
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread('/content/img-process.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=200x100>

# %%
gscl = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2_imshow(gscl)
# Out:
# <PIL.Image.Image image mode=L size=200x100>

# %%
print(gscl.shape)
print(img.shape)
# Out:
# (100, 200)
# (100, 200, 3)

# %%
book = cv2.imread('/content/page-book.jpg')
cv2_imshow(book)
# Out:
# <PIL.Image.Image image mode=RGB size=500x155>

# %%
graybook = cv2.cvtColor(book, cv2.COLOR_BGR2GRAY)
cv2_imshow(graybook)
# Out:
# <PIL.Image.Image image mode=L size=500x155>

# %%
val,thresh = cv2.threshold(graybook,127,255, cv2.THRESH_BINARY)
cv2_imshow(thresh)
# Out:
# <PIL.Image.Image image mode=L size=500x155>

# %%
val, thresh = cv2.threshold(graybook,180,255, cv2.THRESH_BINARY)
cv2_imshow(thresh)
# Out:
# <PIL.Image.Image image mode=L size=500x155>

# %%
val, thresh = cv2.threshold(graybook,140,255,cv2.THRESH_BINARY)
cv2_imshow(thresh)
# Out:
# <PIL.Image.Image image mode=L size=500x155>

# %% [markdown]
# **Otsu Method**

# %%
val, otsu = cv2.threshold(graybook,0,255, cv2.THRESH_OTSU)
cv2_imshow(otsu)
# Out:
# <PIL.Image.Image image mode=L size=500x155>

# %%
val, otsu = cv2.threshold(graybook,0,255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)
cv2_imshow(otsu)
# Out:
# <PIL.Image.Image image mode=L size=500x155>

# %%
bk2 = cv2.imread('/content/book02.jpg')
cv2_imshow(bk2)
grbk = cv2.cvtColor(bk2,cv2.COLOR_BGR2GRAY)
cv2_imshow(graybook)
# Out:
# <PIL.Image.Image image mode=RGB size=589x194>
# <PIL.Image.Image image mode=L size=500x155>

# %%
val,otsu = cv2.threshold(graybook,0,255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)
cv2_imshow(otsu)
# Out:
# <PIL.Image.Image image mode=L size=500x155>

# %%
adaptive_average = cv2.adaptiveThreshold(graybook, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 11, 9)
cv2_imshow(adaptive_average)
# Out:
# <PIL.Image.Image image mode=L size=500x155>

# %%
bkadp = cv2.imread('/content/book_adaptative.jpg')
cv2_imshow(bkadp)
# Out:
# <PIL.Image.Image image mode=RGB size=600x412>

# %%
gradap = cv2.cvtColor(bkadp,cv2.COLOR_BGR2GRAY)
cv2_imshow(gradap)
# Out:
# <PIL.Image.Image image mode=L size=600x412>

# %%
adpgau = cv2.adaptiveThreshold(gradap,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY,11,9)
cv2_imshow(adpgau)
# Out:
# <PIL.Image.Image image mode=L size=600x412>

# %%
adpmean = cv2.adaptiveThreshold(gradap,255,cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY,11,9)
cv2_imshow(adpmean)
# Out:
# <PIL.Image.Image image mode=L size=600x412>
